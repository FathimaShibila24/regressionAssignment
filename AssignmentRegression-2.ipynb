# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('/content/car_age_price.csv')

# %%
data
# Out:
#      Year   Price
# 0    2018  465000
# 1    2019  755000
# 2    2019  700000
# 3    2018  465000
# 4    2018  465000
# ..    ...     ...
# 107  2016  375000
# 108  2014  300000
# 109  2015  425000
# 110  2016  420000
# 111  2015  425000
#
# [112 rows x 2 columns]

# %%
data.head()
# Out:
#    Year   Price
# 0  2018  465000
# 1  2019  755000
# 2  2019  700000
# 3  2018  465000
# 4  2018  465000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112 entries, 0 to 111
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Year    112 non-null    int64
#  1   Price   112 non-null    int64
# dtypes: int64(2)
# memory usage: 1.9 KB

# %%
data.isna().sum()
# Out:
# Year     0
# Price    0
# dtype: int64

# %%
corr_metrix = data.corr()
plt.subplots(figsize = (10,4))
sns.heatmap(corr_metrix,linewidths=0.2,annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %%
x = data[['Year']]
y = data[['Price']]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model = model.fit(x_train,y_train)

# %%
pred =model.predict(x_test)

# %%
pred
# Out:
# array([[600775.91252081],
#        [505558.77690466],
#        [553167.34471273],
#        [553167.34471273],
#        [553167.34471273],
#        [410341.6412885 ],
#        [505558.77690466],
#        [553167.34471273],
#        [600775.91252081],
#        [600775.91252081],
#        [315124.50567235],
#        [505558.77690466],
#        [410341.6412885 ],
#        [648384.48032889],
#        [553167.34471273],
#        [600775.91252081],
#        [315124.50567235],
#        [410341.6412885 ],
#        [505558.77690466],
#        [505558.77690466],
#        [505558.77690466],
#        [505558.77690466],
#        [505558.77690466]])

# %%
x_test
# Out:
#      Year
# 40   2019
# 65   2017
# 4    2018
# 47   2018
# 42   2018
# 69   2015
# 26   2017
# 11   2018
# 10   2019
# 44   2019
# 73   2013
# 55   2017
# 68   2015
# 97   2020
# 0    2018
# 18   2019
# 53   2013
# 80   2015
# 103  2017
# 91   2017
# 36   2017
# 12   2017
# 31   2017

# %%
y_test
# Out:
#       Price
# 40   525000
# 65   495000
# 4    465000
# 47   450000
# 42   550000
# 69   300000
# 26   550000
# 11   500000
# 10   500000
# 44   550000
# 73   320000
# 55   550000
# 68   465000
# 97   640000
# 0    465000
# 18   500000
# 53   345000
# 80   390000
# 103  375000
# 91   520000
# 36   550000
# 12   500000
# 31   550000

# %%
from sklearn.metrics import mean_squared_error
print('MSE is:\n',mean_squared_error(y_test,pred))
# Out:
# MSE is:
#  4326906256.829671

# %%
year_2022 = np.array([[2022]])
predicted_price_2022 = model.predict(year_2022)[0]

print(f"Predicted Price for 2022 Model: ₹{predicted_price_2022[0]:.2f}")
# Out:
# Predicted Price for 2022 Model: ₹743601.62

# %%
#Lasso Regression

# %%
from sklearn.linear_model import Lasso

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.2, random_state=42)

# %%
lasso_model = Lasso(alpha=0.1)

# %%
lasso_model = lasso_model.fit(x_train,y_train)

# %%
lasso_pred = lasso.predict(x_test)

# %%
lasso_pred
# Out:
# array([600775.81201603, 505558.75884159, 553167.28542881, 553167.28542881,
#        553167.28542881, 410341.70566715, 505558.75884159, 553167.28542881,
#        600775.81201603, 600775.81201603, 315124.65249272, 505558.75884159,
#        410341.70566715, 648384.33860324, 553167.28542881, 600775.81201603,
#        315124.65249272, 410341.70566715, 505558.75884159, 505558.75884159,
#        505558.75884159, 505558.75884159, 505558.75884159])

# %%
from sklearn.metrics import mean_squared_error
print('MSE is:\n',mean_squared_error(y_test,lasso_pred))
# Out:
# MSE is:
#  4326901608.19506

# %%
year_2022 = np.array([[2022]])
predicted_price_2022 = lasso_model.predict(year_2022)[0]

print(f"Predicted Price for 2022 Model: ₹{predicted_price_2022:.2f}")
# Out:
# Predicted Price for 2022 Model: ₹743601.39

# %% [markdown]
# Both Linear Regression and Lesso Regression predicts the same price for the 2022 Model grandi10.
